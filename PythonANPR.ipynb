# %% [markdown]
# 1.Install Dependencies

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Collecting easyocr
#   Using cached easyocr-1.6.2-py3-none-any.whl (2.9 MB)
# Collecting opencv-python-headless<=4.5.4.60
#   Downloading opencv_python_headless-4.5.4.60-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: scipy in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: PyYAML in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (6.0)
# Requirement already satisfied: numpy in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (1.21.5)
# Requirement already satisfied: Pillow in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: torchvision>=0.5 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (0.14.1)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 819.5 kB/s eta 0:00:000:00:01
# Requirement already satisfied: scikit-image in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (0.19.2)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (608 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 kB 2.0 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: torch in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from easyocr) (1.13.1)
# Collecting python-bidi
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting Shapely
#   Downloading shapely-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: typing_extensions in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: requests in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: six in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: packaging>=20.0 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/khgunindro/anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Installing collected packages: pyclipper, ninja, Shapely, python-bidi, opencv-python-headless, easyocr
# Successfully installed Shapely-2.0.0 easyocr-1.6.2 ninja-1.11.1 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post4 python-bidi-0.4.2
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25836 sha256=983b6480ac343b749d2a18832bed43b618783989945b574a8b8800afe2ae721c
#   Stored in directory: /home/khgunindro/.cache/pip/wheels/4b/a5/2d/4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %% [markdown]
# 2.Import Dependencies

# %%
import cv2 
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# 3.Read in Image, Grayscale and Blur

# %%
image = cv2.imread('car1.webp')
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 4.Apply filter and find edges for localisation

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17)
edged = cv2.Canny(bfilter, 30, 200)
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))
